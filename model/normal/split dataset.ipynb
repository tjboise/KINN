# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the dataset
filename = 'normal.xlsx'  # Replace with your file path if necessary
sheetname = 'age7'
df = pd.read_excel(filename, sheet_name=sheetname, header=0)

# Define features and target
# X = df[['PC', 'PC_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 
#         'VOID', 'w/b', 'b/a', 'CAGG%', 'FAGG%']]
# y = df['fc (MPa)']

# Split the data into training and testing sets
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# Save training data to an Excel file
# train_data = pd.concat([Xtrain, ytrain.reset_index(drop=True)], axis=1)
train_data.to_excel('train_data.xlsx',sheet_name=sheetname, index=False)

# Save testing data to an Excel file
# test_data = pd.concat([Xtest, ytest.reset_index(drop=True)], axis=1)
test_data.to_excel('test_data.xlsx',sheet_name=sheetname, index=False)

print("Training and testing data have been saved to 'train_data.xlsx' and 'test_data.xlsx'.")
# Out:
# Training and testing data have been saved to 'train_data.xlsx' and 'test_data.xlsx'.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import openpyxl

# Load the dataset
filename = 'normal.xlsx'  # Replace with your file path if necessary
sheetname = 'age56'
df = pd.read_excel(filename, sheet_name=sheetname, header=0)

# Split the data into training and testing sets
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# Function to save data to Excel file, adding a new sheet if the file already exists
def save_to_excel(data, file_path, sheet_name):
    try:
        # Try loading the existing workbook
        with pd.ExcelWriter(file_path, engine='openpyxl', mode='a') as writer:
            data.to_excel(writer, sheet_name=sheet_name, index=False)
    except FileNotFoundError:
        # Create a new workbook if the file doesn't exist
        with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
            data.to_excel(writer, sheet_name=sheet_name, index=False)

# Save training data to Excel
save_to_excel(train_data, 'train_data.xlsx', sheetname)

# Save testing data to Excel
save_to_excel(test_data, 'test_data.xlsx', sheetname)

print("Training and testing data have been saved to 'train_data.xlsx' and 'test_data.xlsx'.")
# Out:
# Training and testing data have been saved to 'train_data.xlsx' and 'test_data.xlsx'.
