# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# %%
# Load and preprocess the data
df_ori = pd.read_excel(r'updated_fc_predictions_with_fc_hat_FA.xlsx', sheet_name='Sheet1')


# Define features and target
X_ori = df_ori[['AGE', 'PC', 'PC_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 
        'VOID', 'w/b', 'b/a', 'CAGG%', 'FAGG%', 'FA%', 'SS%', 'SF%','residual']].values
y_ori = df_ori['fc (MPa)'].values


# Step 1: Split the original data into training and testing sets
Xtrain, Xtest, ytrain, ytest = train_test_split(X_ori, y_ori, train_size=0.8, random_state=42)

# Convert NumPy arrays to pandas DataFrame/Series for concatenation
Xtrain = pd.DataFrame(Xtrain, columns=['AGE', 'PC', 'PC_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 
                                          'AEA', 'WR_HR', 'WR', 'ACC', 'VOID', 'w/b', 'b/a', 'CAGG%', 
                                          'FAGG%', 'FA%', 'SS%', 'SF%','residual'])
ytrain = pd.Series(ytrain, name='fc (MPa)')

Xtest = pd.DataFrame(Xtest, columns = Xtrain.columns)
ytest = pd.Series(ytest, name = 'fc (MPa)')

# Step 1: Combine features and target into a single DataFrame
train_data = pd.concat([Xtrain, ytrain], axis=1)

test_data = pd.concat([Xtest, ytest], axis=1)
# # Step 2: Split into training and test sets
# train_data, test_data = train_test_split(train_combined, test_size=0.2, random_state=42)

# Set the label (target) column
label = 'fc (MPa)'  # The target column (compressive strength)

# Step 3: Train the AutoGluon model
predictor = TabularPredictor(label=label, problem_type='regression').fit(train_data, presets='best_quality')

# Step 4: Get a list of all model names from the leaderboard
all_models = predictor.get_model_names()

# Step 5: Collect metrics for each model
metrics = []
for model_name in all_models:
    y_pred = predictor.predict(test_data, model=model_name)
    r2 = r2_score(test_data[label], y_pred)
    rmse = np.sqrt(mean_squared_error(test_data[label], y_pred))
    mae = mean_absolute_error(test_data[label], y_pred)
    metrics.append({'Model': model_name, 'R2': r2, 'RMSE': rmse, 'MAE': mae})

# Convert the metrics list to a DataFrame for better visualization
metrics_df = pd.DataFrame(metrics)

print(metrics_df)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241015_200554"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.15
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 20.6.0: Wed Jun 23 00:26:31 PDT 2021; root:xnu-7195.141.2~5/RELEASE_X86_64
# CPU Count:          8
# Memory Avail:       6.23 GB / 16.00 GB (38.9%)
# Disk Space Avail:   44.04 GB / 465.63 GB (9.5%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/predictor/predictor.py:1242: UserWarning: Failed to use ray for memory safe fits. Falling back to normal fit. Error: ValueError('ray==2.31.0 detected. 2.10.0 <= ray < 2.11.0 is required. You can use pip to install certain version of ray `pip install ray==2.10.0` ')
#   stacked_overfitting = self._sub_fit_memory_save_wrapper(
# 		Context path: "AutogluonModels/ag-20241015_200554/ds_sub_fit/sub_fit_ho"
# Running DyStack sub-fit ...
# Beginning AutoGluon training ... Time limit = 899s
# AutoGluon will save models to "AutogluonModels/ag-20241015_200554/ds_sub_fit/sub_fit_ho"
# Train Data Rows:    4801
# Train Data Columns: 22
# Label Column:       fc (MPa)
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6217.66 MB
# 	Train Data (Original)  Memory Usage: 0.81 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 22 | ['AGE', 'PC', 'PC_TYPE', 'FA', 'SS', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 22 | ['AGE', 'PC', 'PC_TYPE', 'FA', 'SS', ...]
# 	0.1s = Fit runtime
# 	22 features in original data used to generate 22 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.81 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.14s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 599.11s of the 898.87s of remaining time.
# 	-8.3622	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 594.14s of the 893.9s of remaining time.
# 	-7.5308	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 594.08s of the 893.84s of remaining time.
# Will use sequential fold fitting strategy because import of ray failed. Reason: ray==2.31.0 detected. 2.10.0 <= ray < 2.11.0 is required. You can use pip to install certain version of ray `pip install ray==2.10.0`
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [1000]	valid_set's rmse: 0.867881
# [2000]	valid_set's rmse: 0.82308
# [3000]	valid_set's rmse: 0.818585
# [4000]	valid_set's rmse: 0.818752
# [1000]	valid_set's rmse: 1.66643
# [2000]	valid_set's rmse: 1.60414
# [3000]	valid_set's rmse: 1.56631
# [4000]	valid_set's rmse: 1.55323
# [5000]	valid_set's rmse: 1.53534
# [6000]	valid_set's rmse: 1.52615
# [7000]	valid_set's rmse: 1.52077
# [8000]	valid_set's rmse: 1.51736
# [9000]	valid_set's rmse: 1.51353
# [10000]	valid_set's rmse: 1.5112
# [1000]	valid_set's rmse: 0.861649
# [2000]	valid_set's rmse: 0.844805
# [3000]	valid_set's rmse: 0.84172
# [1000]	valid_set's rmse: 1.04135
# [2000]	valid_set's rmse: 0.97689
# [3000]	valid_set's rmse: 0.947377
# [4000]	valid_set's rmse: 0.933654
# [5000]	valid_set's rmse: 0.921072
# [6000]	valid_set's rmse: 0.916317
# [7000]	valid_set's rmse: 0.908976
# [8000]	valid_set's rmse: 0.903144
# [9000]	valid_set's rmse: 0.899777
# [10000]	valid_set's rmse: 0.89761
# [1000]	valid_set's rmse: 0.957583
# [2000]	valid_set's rmse: 0.928557
# [3000]	valid_set's rmse: 0.919214
# [4000]	valid_set's rmse: 0.916628
# [1000]	valid_set's rmse: 0.887036
# [2000]	valid_set's rmse: 0.854879
# [3000]	valid_set's rmse: 0.840628
# [4000]	valid_set's rmse: 0.836957
# [5000]	valid_set's rmse: 0.833158
# [6000]	valid_set's rmse: 0.832001
# [7000]	valid_set's rmse: 0.831914
# [8000]	valid_set's rmse: 0.832137
# [1000]	valid_set's rmse: 1.05638
# [2000]	valid_set's rmse: 1.01849
# [3000]	valid_set's rmse: 1.0019
# [4000]	valid_set's rmse: 0.99126
# [5000]	valid_set's rmse: 0.981827
# [6000]	valid_set's rmse: 0.974642
# [7000]	valid_set's rmse: 0.96941
# [8000]	valid_set's rmse: 0.96557
# [9000]	valid_set's rmse: 0.96341
# [10000]	valid_set's rmse: 0.962257
# 	-1.01	 = Validation score   (-root_mean_squared_error)
# 	39.29s	 = Training   runtime
# 	1.77s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 550.69s of the 850.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# [1000]	valid_set's rmse: 0.555487
# [1000]	valid_set's rmse: 1.1606
# [1000]	valid_set's rmse: 0.622507
# [1000]	valid_set's rmse: 0.618125
# [2000]	valid_set's rmse: 0.584221
# [3000]	valid_set's rmse: 0.573909
# [4000]	valid_set's rmse: 0.568296
# [5000]	valid_set's rmse: 0.566132
# [6000]	valid_set's rmse: 0.567225
# [1000]	valid_set's rmse: 0.491583
# [2000]	valid_set's rmse: 0.475019
# [3000]	valid_set's rmse: 0.472191
# [4000]	valid_set's rmse: 0.47163
# [1000]	valid_set's rmse: 0.430858
# [1000]	valid_set's rmse: 0.576536
# [2000]	valid_set's rmse: 0.566404
# 	-0.6652	 = Validation score   (-root_mean_squared_error)
# 	17.39s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 531.94s of the 831.7s of remaining time.
# 	-0.8485	 = Validation score   (-root_mean_squared_error)
# 	3.08s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 528.37s of the 828.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, early stopping on iteration 9329.
# 	Ran out of time, early stopping on iteration 9440.
# 	Ran out of time, early stopping on iteration 7971.
# 	Ran out of time, early stopping on iteration 9100.
# 	Ran out of time, early stopping on iteration 9833.
# 	Ran out of time, early stopping on iteration 9742.
# 	-0.5449	 = Validation score   (-root_mean_squared_error)
# 	471.64s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 56.25s of the 356.01s of remaining time.
# 	-0.7267	 = Validation score   (-root_mean_squared_error)
# 	1.14s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 54.5s of the 354.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# 	-0.4834	 = Validation score   (-root_mean_squared_error)
# 	31.43s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 22.83s of the 322.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-0.7107	 = Validation score   (-root_mean_squared_error)
# 	20.52s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1.93s of the 301.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 0.13s of the 299.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, early stopping on iteration 1. Best iteration is:
# 	[1]	valid_set's rmse: 13.6374
# 	Time limit exceeded... Skipping LightGBMLarge_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 299.52s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 0.5, 'CatBoost_BAG_L1': 0.312, 'RandomForestMSE_BAG_L1': 0.125, 'LightGBM_BAG_L1': 0.062}
# 	-0.3441	 = Validation score   (-root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 299.49s of the 299.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# [1000]	valid_set's rmse: 0.670085
# [2000]	valid_set's rmse: 0.66224
# [3000]	valid_set's rmse: 0.657842
# [1000]	valid_set's rmse: 0.891978
# [2000]	valid_set's rmse: 0.885163
# [1000]	valid_set's rmse: 0.79374
# [2000]	valid_set's rmse: 0.750067
# [3000]	valid_set's rmse: 0.724941
# [4000]	valid_set's rmse: 0.712627
# [5000]	valid_set's rmse: 0.704264
# [6000]	valid_set's rmse: 0.699647
# [7000]	valid_set's rmse: 0.696347
# [8000]	valid_set's rmse: 0.692967
# [9000]	valid_set's rmse: 0.690398
# [10000]	valid_set's rmse: 0.688933
# [1000]	valid_set's rmse: 0.755249
# [1000]	valid_set's rmse: 0.53174
# [2000]	valid_set's rmse: 0.513172
# [3000]	valid_set's rmse: 0.504083
# [4000]	valid_set's rmse: 0.499078
# [5000]	valid_set's rmse: 0.495101
# [6000]	valid_set's rmse: 0.49212
# [7000]	valid_set's rmse: 0.490076
# [8000]	valid_set's rmse: 0.488741
# [9000]	valid_set's rmse: 0.486521
# [10000]	valid_set's rmse: 0.485541
# [1000]	valid_set's rmse: 0.591024
# [2000]	valid_set's rmse: 0.567333
# [3000]	valid_set's rmse: 0.561054
# [4000]	valid_set's rmse: 0.557839
# [5000]	valid_set's rmse: 0.56077
# [1000]	valid_set's rmse: 1.11512
# [2000]	valid_set's rmse: 1.07236
# [3000]	valid_set's rmse: 1.04549
# [4000]	valid_set's rmse: 1.03031
# [5000]	valid_set's rmse: 1.01542
# [6000]	valid_set's rmse: 1.00414
# [7000]	valid_set's rmse: 0.992922
# [8000]	valid_set's rmse: 0.982475
# [9000]	valid_set's rmse: 0.974957
# [10000]	valid_set's rmse: 0.969782
# 	-0.8249	 = Validation score   (-root_mean_squared_error)
# 	44.56s	 = Training   runtime
# 	1.84s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 250.63s of the 250.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# [1000]	valid_set's rmse: 0.516193
# [2000]	valid_set's rmse: 0.503929
# [1000]	valid_set's rmse: 0.59678
# [1000]	valid_set's rmse: 0.750966
# [1000]	valid_set's rmse: 0.352751
# [2000]	valid_set's rmse: 0.346827
# [3000]	valid_set's rmse: 0.344811
# [4000]	valid_set's rmse: 0.344465
# [5000]	valid_set's rmse: 0.344841
# 	-0.6239	 = Validation score   (-root_mean_squared_error)
# 	27.11s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 222.55s of the 222.49s of remaining time.
# 	-0.2887	 = Validation score   (-root_mean_squared_error)
# 	5.39s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 216.7s of the 216.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, early stopping on iteration 4741.
# 	Ran out of time, early stopping on iteration 4412.
# 	Ran out of time, early stopping on iteration 5199.
# 	Ran out of time, early stopping on iteration 5289.
# 	Ran out of time, early stopping on iteration 5405.
# 	Ran out of time, early stopping on iteration 7543.
# 	-0.5356	 = Validation score   (-root_mean_squared_error)
# 	204.63s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 11.68s of the 11.61s of remaining time.
# 	-0.312	 = Validation score   (-root_mean_squared_error)
# 	2.4s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 8.24s of remaining time.
# 	Ensemble Weights: {'RandomForestMSE_BAG_L2': 0.6, 'NeuralNetFastAI_BAG_L1': 0.2, 'ExtraTreesMSE_BAG_L2': 0.2}
# 	-0.2678	 = Validation score   (-root_mean_squared_error)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 890.87s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 223.2 rows/s (601 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241015_200554/ds_sub_fit/sub_fit_ho")
# Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                      model  score_holdout  score_val              eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3      -0.283235  -0.267832  root_mean_squared_error       13.598958       3.650422  592.322834                 0.007390                0.000397           0.031106            3       True         16
# 1     ExtraTreesMSE_BAG_L2      -0.292488  -0.312024  root_mean_squared_error        8.166842       3.406045  586.905680                 1.138178                0.297575           2.397929            2       True         15
# 2   RandomForestMSE_BAG_L2      -0.306160  -0.288664  root_mean_squared_error       12.453391       3.352450  589.893799                 5.424726                0.243980           5.386048            2       True         13
# 3      WeightedEnsemble_L2      -0.358111  -0.344070  root_mean_squared_error        3.125873       0.902091  523.552498                 0.003205                0.000423           0.015077            2       True         10
# 4   NeuralNetFastAI_BAG_L1      -0.401728  -0.483390  root_mean_squared_error        0.742618       0.107051   31.427815                 0.742618                0.107051          31.427815            1       True          8
# 5          CatBoost_BAG_L2      -0.507250  -0.535607  root_mean_squared_error        7.538213       3.158310  789.135244                 0.509549                0.049840         204.627493            2       True         14
# 6          CatBoost_BAG_L1      -0.541357  -0.544905  root_mean_squared_error        0.338509       0.040023  471.641185                 0.338509                0.040023         471.641185            1       True          6
# 7           XGBoost_BAG_L1      -0.610315  -0.710746  root_mean_squared_error        0.636285       0.095276   20.518092                 0.636285                0.095276          20.518092            1       True          9
# 8     ExtraTreesMSE_BAG_L1      -0.777670  -0.726700  root_mean_squared_error        0.523322       0.209022    1.144225                 0.523322                0.209022           1.144225            1       True          7
# 9          LightGBM_BAG_L2      -0.834805  -0.623889  root_mean_squared_error        7.754048       3.499952  611.622203                 0.725383                0.391482          27.114453            2       True         12
# 10       LightGBMXT_BAG_L2      -0.849890  -0.824942  root_mean_squared_error       10.051206       4.946296  629.069223                 3.022541                1.837826          44.561472            2       True         11
# 11  RandomForestMSE_BAG_L1      -0.884507  -0.848490  root_mean_squared_error        1.029201       0.207444    3.081966                 1.029201                0.207444           3.081966            1       True          5
# 12         LightGBM_BAG_L1      -0.888162  -0.665150  root_mean_squared_error        1.012340       0.547151   17.386455                 1.012340                0.547151          17.386455            1       True          4
# 13       LightGBMXT_BAG_L1      -1.092943  -1.009979  root_mean_squared_error        2.710013       1.766288   39.293988                 2.710013                1.766288          39.293988            1       True          3
# 14   KNeighborsDist_BAG_L1      -7.417099  -7.530838  root_mean_squared_error        0.009327       0.035624    0.008191                 0.009327                0.035624           0.008191            1       True          2
# 15   KNeighborsUnif_BAG_L1      -8.019900  -8.362177  root_mean_squared_error        0.027049       0.100591    0.005833                 0.027049                0.100591           0.005833            1       True          1
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	911s	 = DyStack   runtime |	2689s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 2689s
# AutoGluon will save models to "AutogluonModels/ag-20241015_200554"
# Train Data Rows:    5402
# Train Data Columns: 22
# Label Column:       fc (MPa)
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2210.07 MB
# 	Train Data (Original)  Memory Usage: 0.91 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 22 | ['AGE', 'PC', 'PC_TYPE', 'FA', 'SS', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 22 | ['AGE', 'PC', 'PC_TYPE', 'FA', 'SS', ...]
# 	0.1s = Fit runtime
# 	22 features in original data used to generate 22 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.91 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.2s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1792.27s of the 2689.03s of remaining time.
# 	-8.1519	 = Validation score   (-root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1792.11s of the 2688.88s of remaining time.
# 	-7.3125	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1792.01s of the 2688.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# [1000]	valid_set's rmse: 0.850375
# [1000]	valid_set's rmse: 1.04892
# [2000]	valid_set's rmse: 1.01373
# [3000]	valid_set's rmse: 1.00317
# [4000]	valid_set's rmse: 0.999206
# [5000]	valid_set's rmse: 0.997726
# [6000]	valid_set's rmse: 0.997307
# [7000]	valid_set's rmse: 0.997012
# [8000]	valid_set's rmse: 0.997631
# [1000]	valid_set's rmse: 1.08587
# [2000]	valid_set's rmse: 1.02631
# [3000]	valid_set's rmse: 1.00775
# [4000]	valid_set's rmse: 0.998122
# [5000]	valid_set's rmse: 0.989115
# [6000]	valid_set's rmse: 0.984726
# [7000]	valid_set's rmse: 0.982463
# [8000]	valid_set's rmse: 0.982984
# [9000]	valid_set's rmse: 0.983778
# [1000]	valid_set's rmse: 1.2484
# [2000]	valid_set's rmse: 1.20996
# [3000]	valid_set's rmse: 1.19796
# [4000]	valid_set's rmse: 1.19312
# [5000]	valid_set's rmse: 1.18913
# [6000]	valid_set's rmse: 1.18727
# [7000]	valid_set's rmse: 1.18544
# [8000]	valid_set's rmse: 1.18248
# [9000]	valid_set's rmse: 1.18099
# [10000]	valid_set's rmse: 1.18043
# [1000]	valid_set's rmse: 0.973795
# [2000]	valid_set's rmse: 0.951491
# [3000]	valid_set's rmse: 0.942633
# [1000]	valid_set's rmse: 1.10145
# [2000]	valid_set's rmse: 1.06089
# [3000]	valid_set's rmse: 1.05326
# [4000]	valid_set's rmse: 1.05277
# [5000]	valid_set's rmse: 1.05451
# [1000]	valid_set's rmse: 1.10244
# [2000]	valid_set's rmse: 1.02477
# [3000]	valid_set's rmse: 0.994922
# [4000]	valid_set's rmse: 0.985626
# [5000]	valid_set's rmse: 0.976607
# [6000]	valid_set's rmse: 0.971545
# [7000]	valid_set's rmse: 0.967665
# [8000]	valid_set's rmse: 0.965188
# [9000]	valid_set's rmse: 0.964483
# [10000]	valid_set's rmse: 0.963915
# [1000]	valid_set's rmse: 0.989061
# [2000]	valid_set's rmse: 0.943806
# [3000]	valid_set's rmse: 0.937095
# [4000]	valid_set's rmse: 0.926374
# [5000]	valid_set's rmse: 0.921344
# [6000]	valid_set's rmse: 0.91608
# [7000]	valid_set's rmse: 0.913332
# [8000]	valid_set's rmse: 0.910766
# [9000]	valid_set's rmse: 0.908647
# [10000]	valid_set's rmse: 0.906614
# 	-0.9883	 = Validation score   (-root_mean_squared_error)
# 	60.15s	 = Training   runtime
# 	2.4s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1726.35s of the 2623.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# [1000]	valid_set's rmse: 0.693343
# [2000]	valid_set's rmse: 0.686227
# [1000]	valid_set's rmse: 0.683078
# [2000]	valid_set's rmse: 0.671741
# [3000]	valid_set's rmse: 0.669701
# [1000]	valid_set's rmse: 0.844034
# [1000]	valid_set's rmse: 0.621377
# [2000]	valid_set's rmse: 0.619044
# [1000]	valid_set's rmse: 0.600383
# [2000]	valid_set's rmse: 0.593242
# [1000]	valid_set's rmse: 0.687313
# [2000]	valid_set's rmse: 0.675412
# 	-0.7064	 = Validation score   (-root_mean_squared_error)
# 	18.5s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 1706.73s of the 2603.49s of remaining time.
# 	-0.8138	 = Validation score   (-root_mean_squared_error)
# 	4.71s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1701.38s of the 2598.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-0.5263	 = Validation score   (-root_mean_squared_error)
# 	600.65s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 1100.18s of the 1996.94s of remaining time.
# 	-0.6995	 = Validation score   (-root_mean_squared_error)
# 	1.49s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1097.41s of the 1994.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# 	-0.4391	 = Validation score   (-root_mean_squared_error)
# 	44.04s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1053.06s of the 1949.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-0.6614	 = Validation score   (-root_mean_squared_error)
# 	46.92s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1005.28s of the 1902.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# ...
#   self.model = torch.load(net_filename)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(net_filename)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(net_filename)
# 	-1.542	 = Validation score   (-root_mean_squared_error)
# 	36.03s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 301.22s of the 301.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# [1000]	valid_set's rmse: 0.280573
# [2000]	valid_set's rmse: 0.279857
# [3000]	valid_set's rmse: 0.279534
# [4000]	valid_set's rmse: 0.27939
# [5000]	valid_set's rmse: 0.279347
# [6000]	valid_set's rmse: 0.279336
# [7000]	valid_set's rmse: 0.279333
# [8000]	valid_set's rmse: 0.279332
# [9000]	valid_set's rmse: 0.279332
# 	Ran out of time, early stopping on iteration 9671. Best iteration is:
# 	[9671]	valid_set's rmse: 0.279332
# [1000]	valid_set's rmse: 0.246182
# 	-0.4066	 = Validation score   (-root_mean_squared_error)
# 	65.41s	 = Training   runtime
# 	1.14s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 232.38s of the 232.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, early stopping on iteration 4220.
# 	Ran out of time, early stopping on iteration 4453.
# 	Ran out of time, early stopping on iteration 4198.
# 	Ran out of time, early stopping on iteration 5030.
# 	Ran out of time, early stopping on iteration 6226.
# 	Ran out of time, early stopping on iteration 6471.
# 	Ran out of time, early stopping on iteration 7469.
# 	-0.4786	 = Validation score   (-root_mean_squared_error)
# 	220.58s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 11.58s of the 11.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, stopping training early. (Stopping on epoch 4)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(net_filename)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(net_filename)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(net_filename)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(net_filename)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(net_filename)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(net_filename)
# 	Ran out of time, stopping training early. (Stopping on epoch 5)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(net_filename)
# 	Ran out of time, stopping training early. (Stopping on epoch 7)
# /Users/zhangtianjie/opt/anaconda3/envs/autogluon/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(net_filename)
# 	-1.8302	 = Validation score   (-root_mean_squared_error)
# 	10.87s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -0.06s of remaining time.
# 	Ensemble Weights: {'RandomForestMSE_BAG_L2': 0.5, 'ExtraTreesMSE_BAG_L2': 0.25, 'NeuralNetFastAI_r191_BAG_L1': 0.15, 'NeuralNetFastAI_BAG_L1': 0.1}
# 	-0.2187	 = Validation score   (-root_mean_squared_error)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2689.43s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 69.9 rows/s (676 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241015_200554")
# /var/folders/m1/ws2562m105bdpyh7s345x7cw0000gn/T/ipykernel_24553/1165002634.py:37: DeprecationWarning: `get_model_names` has been deprecated and will be removed in version 1.2. Please use `model_names` instead. This will raise an error in the future!
#   all_models = predictor.get_model_names()
#                           Model        R2      RMSE       MAE
# 0         KNeighborsUnif_BAG_L1  0.665503  8.105702  5.853567
# 1         KNeighborsDist_BAG_L1  0.720942  7.403581  5.142876
# 2             LightGBMXT_BAG_L1  0.995210  0.969990  0.484733
# 3               LightGBM_BAG_L1  0.998280  0.581313  0.234497
# 4        RandomForestMSE_BAG_L1  0.997388  0.716287  0.369889
# 5               CatBoost_BAG_L1  0.999266  0.379715  0.114660
# 6          ExtraTreesMSE_BAG_L1  0.998543  0.535029  0.254772
# 7        NeuralNetFastAI_BAG_L1  0.999483  0.318787  0.206926
# 8                XGBoost_BAG_L1  0.998984  0.446786  0.195184
# 9         NeuralNetTorch_BAG_L1  0.993458  1.133583  0.801596
# 10         LightGBMLarge_BAG_L1  0.998511  0.540766  0.269303
# 11         CatBoost_r177_BAG_L1  0.999279  0.376222  0.117323
# 12    NeuralNetTorch_r79_BAG_L1  0.998323  0.573962  0.289148
# 13         LightGBM_r131_BAG_L1  0.998002  0.626441  0.339796
# 14  NeuralNetFastAI_r191_BAG_L1  0.999696  0.244183  0.160142
# 15           CatBoost_r9_BAG_L1  0.997977  0.630439  0.229773
# 16          LightGBM_r96_BAG_L1  0.983965  1.774707  0.993659
# 17          WeightedEnsemble_L2  0.999769  0.212873  0.117683
# 18            LightGBMXT_BAG_L2  0.996766  0.797063  0.219416
# 19              LightGBM_BAG_L2  0.998863  0.472557  0.136631
# 20       RandomForestMSE_BAG_L2  0.999799  0.198639  0.091390
# 21              CatBoost_BAG_L2  0.999433  0.333813  0.150127
# 22         ExtraTreesMSE_BAG_L2  0.999835  0.179905  0.085358
# 23       NeuralNetFastAI_BAG_L2  0.999494  0.315239  0.170071
# 24               XGBoost_BAG_L2  0.999690  0.246708  0.103158
# 25        NeuralNetTorch_BAG_L2  0.991294  1.307650  0.911006
# 26         LightGBMLarge_BAG_L2  0.999591  0.283610  0.101047
# 27         CatBoost_r177_BAG_L2  0.999438  0.332154  0.143012
# 28    NeuralNetTorch_r79_BAG_L2  0.994708  1.019509  0.478099
# 29          WeightedEnsemble_L3  0.999837  0.179186  0.085539

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# Load and preprocess the data
df_ori = pd.read_excel(r'updated_fc_predictions_with_fc_hat_FA.xlsx', sheet_name='Sheet1')


# Define features and target
X = df_ori[['AGE', 'PC', 'PC_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 
        'VOID', 'w/b', 'b/a', 'CAGG%', 'FAGG%', 'FA%', 'SS%', 'SF%']].values
y = df_ori['fc (MPa)'].values

# Train-test split

# Best parameters from RandomizedSearchCV
best_params = {
    'n_estimators': 500,
    'max_depth': 5,
    'learning_rate': 0.09,
    'gamma': 0.0,
    'colsample_bytree': 0.7
}

mse_scores = []
r2_scores = []

# Run the model 100 times
for i in range(10):
    print(f"Run {i + 1}")
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)

    # Create and fit the XGBoost model
    model = xgb.XGBRegressor(objective='reg:squarederror', **best_params)
    model.fit(X_train, y_train)

    # Make predictions
    predictions = model.predict(X_test)

    # Calculate metrics
    mse = mean_squared_error(y_test, predictions)
    r2 = metrics.r2_score(y_test, predictions)

    # Store metrics
    mse_scores.append(mse)
    r2_scores.append(r2)

# Calculate average and standard deviation
average_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)
average_r2 = np.mean(r2_scores)
std_r2 = np.std(r2_scores)

# Print average and standard deviation
print(f'Average MSE: {average_mse:.4f}, Std MSE: {std_mse:.4f}')
print(f'Average R-squared: {average_r2:.4f}, Std R-squared: {std_r2:.4f}')
# Out:
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Run 10
# Average MSE: 38.1494, Std MSE: 4.1621
# Average R-squared: 0.7984, Std R-squared: 0.0215
