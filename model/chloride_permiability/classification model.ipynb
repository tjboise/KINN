# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Load the dataset
df = pd.read_csv(r'full_results_with_predictions.csv')

# Define features and target
X = df[['AGE', 'PC1', 'PC2', 'PC1_TYPE', 'FA', 'SS', 'SF', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 
        'VOID', 'w/b', 'b/a', 'SCM%', 'APPLICATION_ID']].values

y = df['Chloride Ion Penetrability']

# Convert target labels (Permeability Level) to numerical labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# 1. Random Forest Classifier with Grid Search
rf_param_grid = {
    'n_estimators': [100, 300, 500],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf_grid = GridSearchCV(RandomForestClassifier(random_state=42), rf_param_grid, cv=3, n_jobs=-1, scoring='accuracy')
rf_grid.fit(X_train, y_train)
best_rf = rf_grid.best_estimator_
y_pred_rf = best_rf.predict(X_test)
rf_report = classification_report(y_test, y_pred_rf, target_names=label_encoder.classes_)

# 2. XGBoost Classifier with Grid Search
xgb_param_grid = {
    'n_estimators': [100, 300, 500],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'subsample': [0.7, 0.8, 1],
    'colsample_bytree': [0.7, 0.8, 1]
}

xgb_grid = GridSearchCV(XGBClassifier(random_state=42), xgb_param_grid, cv=3, n_jobs=-1, scoring='accuracy')
xgb_grid.fit(X_train, y_train)
best_xgb = xgb_grid.best_estimator_
y_pred_xgb = best_xgb.predict(X_test)
xgb_report = classification_report(y_test, y_pred_xgb, target_names=label_encoder.classes_)

# 3. MLP Classifier (ANN) with Grid Search
mlp_param_grid = {
    'hidden_layer_sizes': [(50,), (100,), (150,)],
    'activation': ['relu', 'tanh'],
    'learning_rate': ['constant', 'adaptive'],
    'max_iter': [300, 500]
}

mlp_grid = GridSearchCV(MLPClassifier(random_state=42), mlp_param_grid, cv=3, n_jobs=-1, scoring='accuracy')
mlp_grid.fit(X_train, y_train)
best_mlp = mlp_grid.best_estimator_
y_pred_mlp = best_mlp.predict(X_test)
mlp_report = classification_report(y_test, y_pred_mlp, target_names=label_encoder.classes_)

# Displaying the results
print("Best Random Forest Classifier:")
print(f"Best Parameters: {rf_grid.best_params_}")
print(rf_report)

print("Best XGBoost Classifier:")
print(f"Best Parameters: {xgb_grid.best_params_}")
print(xgb_report)

print("Best MLP (ANN) Classifier:")
print(f"Best Parameters: {mlp_grid.best_params_}")
print(mlp_report)
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/ag/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /Users/zhangtianjie/opt/anaconda3/envs/ag/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /Users/zhangtianjie/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/zhangtianjie/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
# Preparing the dataset for model training
# Select features (from AGE to CAGG%) and the target ('chloride ion penetration')
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Load the dataset
df = pd.read_csv(r'full_results_with_predictions.csv')

# X = df.loc[:, 'AGE':'CAGG%']

X = df[['AGE', 'PC1','PC2', 'PC1_TYPE', 'FA', 'SS', 'SF', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 
        'VOID','w/b','b/a','SCM%','APPLICATION_ID']].values

y = df['Chloride Ion Penetrability']

# Convert target labels (Permeability Level) to numerical labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Importing necessary models
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Random Forest Classifier
rf_clf = RandomForestClassifier(n_estimators=500, random_state=42)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)
rf_report = classification_report(y_test, y_pred_rf, target_names=label_encoder.classes_)

# XGBoost Classifier
xgb_clf = XGBClassifier(random_state=42)
xgb_clf.fit(X_train, y_train)
y_pred_xgb = xgb_clf.predict(X_test)
xgb_report = classification_report(y_test, y_pred_xgb, target_names=label_encoder.classes_)

# Artificial Neural Network (ANN) Classifier
ann_clf = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)
ann_clf.fit(X_train, y_train)
y_pred_ann = ann_clf.predict(X_test)
ann_report = classification_report(y_test, y_pred_ann, target_names=label_encoder.classes_)

# Displaying the results
print("Random Forest Classification Report:")
print(rf_report)

print("XGBoost Classification Report:")
print(xgb_report)

print("ANN Classification Report:")
print(ann_report)
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.40      0.18      0.25        11
#          Low       0.55      0.67      0.60        58
#     Moderate       0.29      0.25      0.27        16
#     Very Low       0.85      0.82      0.84       121
#
#     accuracy                           0.70       206
#    macro avg       0.52      0.48      0.49       206
# weighted avg       0.70      0.70      0.70       206
#
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.50      0.27      0.35        11
#          Low       0.55      0.69      0.61        58
#     Moderate       0.33      0.31      0.32        16
#     Very Low       0.86      0.79      0.82       121
#
#     accuracy                           0.70       206
#    macro avg       0.56      0.52      0.53       206
# weighted avg       0.71      0.70      0.70       206
#
# ...

# %%
# Preparing the dataset for model training
# Select features (from AGE to CAGG%) and the target ('chloride ion penetration')
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Load the dataset
df = pd.read_excel(r'chloride_Classification.xlsx',sheet_name='Sheet1')

# X = df.loc[:, 'AGE':'CAGG%']

X = df[['AGE', 'PC1', 'PC2', 'PC1_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 
                'AEA', 'WR_HR', 'WR', 'ACC', 'VOID', 'FIBER', 'SLUMP', 'IS_PUMP', 'IS_LATEX', 
                'LATEX_AMOUNT', 'IS_LIGHT_WEIGHT', 'APPLICATION_ID', 'TOTAL_BINDER', 'TOTAL_AGG', 
                'w/b', 'b/a', 'SCM%', 'FAGG%', 'CAGG%', 'FA%', 'SS%', 'SF%']].values

y = df['Chloride Ion Penetrability Class']

# Convert target labels (Permeability Level) to numerical labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Importing necessary models
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Random Forest Classifier
rf_clf = RandomForestClassifier(n_estimators=500, random_state=42)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)
rf_report = classification_report(y_test, y_pred_rf, target_names=label_encoder.classes_)

# XGBoost Classifier
xgb_clf = XGBClassifier(random_state=42)
xgb_clf.fit(X_train, y_train)
y_pred_xgb = xgb_clf.predict(X_test)
xgb_report = classification_report(y_test, y_pred_xgb, target_names=label_encoder.classes_)

# Artificial Neural Network (ANN) Classifier
ann_clf = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)
ann_clf.fit(X_train, y_train)
y_pred_ann = ann_clf.predict(X_test)
ann_report = classification_report(y_test, y_pred_ann, target_names=label_encoder.classes_)

# Displaying the results
print("Random Forest Classification Report:")
print(rf_report)

print("XGBoost Classification Report:")
print(xgb_report)

print("ANN Classification Report:")
print(ann_report)

# %%
# Preparing the dataset for model training
# Select features (from AGE to CAGG%) and the target ('chloride ion penetration')
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Load the dataset
df = pd.read_csv(r'final_dataset.csv')

X = df.loc[:, 'AGE':'CAGG%']

# X = df[['AGE', 'PC1', 'PC2', 'PC1_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 
#                 'AEA', 'WR_HR', 'WR', 'ACC', 'VOID', 'FIBER', 'SLUMP', 'IS_PUMP', 'IS_LATEX', 
#                 'LATEX_AMOUNT', 'IS_LIGHT_WEIGHT', 'APPLICATION_ID', 'TOTAL_BINDER', 
#                 'w/b', 'b/a', 'SCM%', 'FAGG%', 'CAGG%']].values

y = df['Chloride Ion Penetrability Class']

# Convert target labels (Permeability Level) to numerical labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Importing necessary models
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Random Forest Classifier
rf_clf = RandomForestClassifier(n_estimators=500, random_state=42)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)
rf_report = classification_report(y_test, y_pred_rf, target_names=label_encoder.classes_)

# XGBoost Classifier
xgb_clf = XGBClassifier(random_state=42)
xgb_clf.fit(X_train, y_train)
y_pred_xgb = xgb_clf.predict(X_test)
xgb_report = classification_report(y_test, y_pred_xgb, target_names=label_encoder.classes_)

# Artificial Neural Network (ANN) Classifier
ann_clf = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)
ann_clf.fit(X_train, y_train)
y_pred_ann = ann_clf.predict(X_test)
ann_report = classification_report(y_test, y_pred_ann, target_names=label_encoder.classes_)

# Displaying the results
print("Random Forest Classification Report:")
print(rf_report)

print("XGBoost Classification Report:")
print(xgb_report)

print("ANN Classification Report:")
print(ann_report)
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.33      0.18      0.24        11
#          Low       0.52      0.67      0.59        58
#     Moderate       0.36      0.25      0.30        16
#     Very Low       0.84      0.79      0.82       121
#
#     accuracy                           0.68       206
#    macro avg       0.51      0.47      0.48       206
# weighted avg       0.69      0.68      0.68       206
#
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.38      0.27      0.32        11
#          Low       0.51      0.62      0.56        58
#     Moderate       0.33      0.31      0.32        16
#     Very Low       0.85      0.79      0.82       121
#
#     accuracy                           0.67       206
#    macro avg       0.52      0.50      0.50       206
# weighted avg       0.69      0.67      0.68       206
#
# ...

# %%
# Preparing the dataset for model training
# Select features (from AGE to CAGG%) and the target ('chloride ion penetration')
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Load the dataset
df = pd.read_excel(r'data_aug.xlsx',sheet_name='Sheet1')

# X = df.loc[:, 'AGE':'CAGG%']

X = df[['AGE', 'PC1', 'PC2', 'PC1_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 
                'AEA', 'WR_HR', 'WR', 'ACC', 'VOID', 'FIBER', 'SLUMP', 'IS_PUMP', 'IS_LATEX', 
                'LATEX_AMOUNT', 'IS_LIGHT_WEIGHT', 'APPLICATION_ID', 'TOTAL_BINDER', 'TOTAL_AGG', 
                'w/b', 'b/a', 'SCM%', 'FAGG%', 'CAGG%', 'FA%', 'SS%', 'SF%']].values

y = df['Chloride Ion Penetrability Class']

# Convert target labels (Permeability Level) to numerical labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Importing necessary models
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Random Forest Classifier
rf_clf = RandomForestClassifier(n_estimators=500, random_state=42)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)
rf_report = classification_report(y_test, y_pred_rf, target_names=label_encoder.classes_)

# XGBoost Classifier
xgb_clf = XGBClassifier(random_state=42)
xgb_clf.fit(X_train, y_train)
y_pred_xgb = xgb_clf.predict(X_test)
xgb_report = classification_report(y_test, y_pred_xgb, target_names=label_encoder.classes_)

# Artificial Neural Network (ANN) Classifier
ann_clf = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)
ann_clf.fit(X_train, y_train)
y_pred_ann = ann_clf.predict(X_test)
ann_report = classification_report(y_test, y_pred_ann, target_names=label_encoder.classes_)

# Displaying the results
print("Random Forest Classification Report:")
print(rf_report)

print("XGBoost Classification Report:")
print(xgb_report)

print("ANN Classification Report:")
print(ann_report)
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.39      0.60      0.47       127
#          Low       0.42      0.43      0.42       169
#     Moderate       0.42      0.15      0.22       113
#     Very Low       0.82      0.85      0.83       142
#
#     accuracy                           0.52       551
#    macro avg       0.51      0.50      0.49       551
# weighted avg       0.52      0.52      0.50       551
#
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.39      0.52      0.45       127
#          Low       0.38      0.40      0.39       169
#     Moderate       0.34      0.20      0.26       113
#     Very Low       0.82      0.81      0.82       142
#
#     accuracy                           0.49       551
#    macro avg       0.48      0.48      0.48       551
# weighted avg       0.49      0.49      0.48       551
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Load the dataset from the file
# df = pd.read_csv(r'path_to_your_file.csv')
# Load the dataset
df = pd.read_csv(r'final_dataset.csv')

# X = df.loc[:, 'AGE':'CAGG%']

X = df[['AGE', 'PC1', 'PC2','PC1_TYPE', 'FA', 'SS', 'SF', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 
        'VOID','w/b','b/a','SCM%','APPLICATION_ID']].values

y = df['Chloride Ion Penetrability']

# Convert target labels (Permeability Level) to numerical labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Random Forest Classifier with class weights
rf_clf = RandomForestClassifier(n_estimators=200, random_state=42, class_weight='balanced')
rf_clf.fit(X_train_resampled, y_train_resampled)
y_pred_rf = rf_clf.predict(X_test)
rf_report = classification_report(y_test, y_pred_rf, target_names=label_encoder.classes_)

# XGBoost Classifier with scale_pos_weight to handle imbalance
xgb_clf = XGBClassifier(random_state=42, scale_pos_weight=len(y_train_resampled) / len(y_train))
xgb_clf.fit(X_train_resampled, y_train_resampled)
y_pred_xgb = xgb_clf.predict(X_test)
xgb_report = classification_report(y_test, y_pred_xgb, target_names=label_encoder.classes_)

# Artificial Neural Network (ANN) Classifier
ann_clf = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)
ann_clf.fit(X_train_resampled, y_train_resampled)
y_pred_ann = ann_clf.predict(X_test)
ann_report = classification_report(y_test, y_pred_ann, target_names=label_encoder.classes_)

# Display the classification reports for all models
print("Random Forest Classification Report:")
print(rf_report)

print("XGBoost Classification Report:")
print(xgb_report)

print("ANN Classification Report:")
print(ann_report)
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/ag/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [20:22:03] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1727634900191/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.31      0.45      0.37        11
#          Low       0.51      0.59      0.54        58
#     Moderate       0.26      0.31      0.29        16
#     Very Low       0.89      0.77      0.83       121
#
#     accuracy                           0.67       206
#    macro avg       0.49      0.53      0.51       206
# weighted avg       0.71      0.67      0.68       206
#
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.21      0.27      0.24        11
# ...

# %% [markdown]
# ## after data balanced

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

df_ori = pd.read_csv(r'Updated_Dataset_with_Permeability_Classification.csv')

df_low = pd.read_excel(r'GC_class.xlsx',sheet_name='low')
df_low = df_low.sample(n=425, random_state=42)

df_moderate = pd.read_excel(r'GC_class.xlsx',sheet_name='moderate')
df_moderate = df_moderate.sample(n=593, random_state=42)

df_high = pd.read_excel(r'GC_class.xlsx',sheet_name='high')
df_high = df_high.sample(n=689, random_state=42)


X_ori = df_ori[['AGE', 'PC1', 'PC1_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 'TOTAL_BINDER',
        'VOID', 'w/b', 'b/a', 'CAGG%', 'FAGG%','SCM%']].values

y_ori = df_ori['chloride ion penetration'].values

X_low = df_low[['AGE', 'PC1', 'PC1_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 'TOTAL_BINDER',
        'VOID', 'w/b', 'b/a', 'CAGG%', 'FAGG%','SCM%']].values
y_low = df_low['chloride ion penetration'].values

X_moderate = df_moderate[['AGE', 'PC1', 'PC1_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 'TOTAL_BINDER',
        'VOID', 'w/b', 'b/a', 'CAGG%', 'FAGG%','SCM%']].values
y_moderate = df_moderate['chloride ion penetration'].values

X_high = df_high[['AGE', 'PC1', 'PC1_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 'TOTAL_BINDER',
        'VOID', 'w/b', 'b/a', 'CAGG%', 'FAGG%','SCM%']].values
y_high = df_high['chloride ion penetration'].values

# Step 1: Split the original data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_ori, y_ori, train_size=0.8, random_state=42)

# Convert NumPy arrays to pandas DataFrame/Series for concatenation
X_train_df = pd.DataFrame(X_train, columns=['AGE', 'PC1', 'PC1_TYPE', 'FA', 'SS', 'SF', 'FAGG', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 
                                        'TOTAL_BINDER',
        'VOID', 'w/b', 'b/a', 'CAGG%', 'FAGG%','SCM%'])
y_train_df = pd.Series(y_train, name='chloride ion penetration')

X_low_df = pd.DataFrame(X_low, columns=X_ori_df.columns)
y_low_df = pd.Series(y_low, name='chloride ion penetration')

X_moderate_df = pd.DataFrame(X_moderate, columns=X_ori_df.columns)
y_moderate_df = pd.Series(y_moderate, name='chloride ion penetration')

X_high_df = pd.DataFrame(X_high, columns=X_ori_df.columns)
y_high_df = pd.Series(y_high, name='chloride ion penetration')


# Concatenate training data with synthetic data
X_train_combined = pd.concat([X_train_df, X_low_df,X_moderate_df,X_high_df], axis=0)
y_train_combined = pd.concat([y_train_df, y_low_df,y_moderate_df,y_high_df], axis=0)

# %%
# Convert target labels (Permeability Level) to numerical labels
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
# y_encoded = label_encoder.fit_transform(y_combined)

# X_train, X_test, y_train, y_test = train_test_split(X_ori, y_ori, train_size=0.8, random_state=42)

# Split the data into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X_combined, y_encoded, test_size=0.1, random_state=42)


X_train = X_train_combined
y_train = label_encoder.fit_transform(y_train_combined)
y_test = label_encoder.fit_transform(y_test)

# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Random Forest Classifier with class weights
rf_clf = RandomForestClassifier(n_estimators=200, random_state=42)
rf_clf.fit(X_train_resampled, y_train_resampled)
y_pred_rf = rf_clf.predict(X_test)
rf_report = classification_report(y_test, y_pred_rf, target_names=label_encoder.classes_)

# XGBoost Classifier with scale_pos_weight to handle imbalance
xgb_clf = XGBClassifier(random_state=42)
xgb_clf.fit(X_train_resampled, y_train_resampled)
y_pred_xgb = xgb_clf.predict(X_test)
xgb_report = classification_report(y_test, y_pred_xgb, target_names=label_encoder.classes_)

# Artificial Neural Network (ANN) Classifier
ann_clf = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)
ann_clf.fit(X_train_resampled, y_train_resampled)
y_pred_ann = ann_clf.predict(X_test)
ann_report = classification_report(y_test, y_pred_ann, target_names=label_encoder.classes_)

# Display the classification reports for all models
print("Random Forest Classification Report:")
print(rf_report)

print("XGBoost Classification Report:")
print(xgb_report)

print("ANN Classification Report:")
print(ann_report)
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.33      0.50      0.40         8
#          Low       0.38      0.43      0.41        67
#     Moderate       0.23      0.20      0.21        30
#     Very Low       0.78      0.73      0.75       156
#
#     accuracy                           0.59       261
#    macro avg       0.43      0.47      0.44       261
# weighted avg       0.60      0.59      0.59       261
#
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.30      0.38      0.33         8
#          Low       0.43      0.49      0.46        67
#     Moderate       0.33      0.27      0.30        30
# ...

# %%
# # Apply SMOTE to handle class imbalance
# import pandas as pd
# from sklearn.model_selection import train_test_split, RandomizedSearchCV
# from sklearn.preprocessing import LabelEncoder
# from sklearn.metrics import classification_report
# from imblearn.over_sampling import SMOTE
# from sklearn.ensemble import RandomForestClassifier
# from xgboost import XGBClassifier
# from sklearn.neural_network import MLPClassifier
# from scipy.stats import randint, uniform
# smote = SMOTE(random_state=42)
# X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# # Define parameter grids for each model

# # Random Forest hyperparameter grid
# rf_param_grid = {
#     'n_estimators': randint(100, 500),
#     'max_depth': randint(5, 20),
#     'min_samples_split': randint(2, 10),
#     'min_samples_leaf': randint(1, 4),
#     'bootstrap': [True, False]
# }

# # XGBoost hyperparameter grid
# xgb_param_grid = {
#     'n_estimators': randint(100, 500),
#     'learning_rate': uniform(0.01, 0.3),
#     'max_depth': randint(3, 10),
#     'subsample': uniform(0.6, 1),
#     'colsample_bytree': uniform(0.6, 1)
# }

# # ANN (MLP) hyperparameter grid
# ann_param_grid = {
#     'hidden_layer_sizes': [(100,), (100, 100), (100, 50, 25)],
#     'activation': ['relu', 'tanh'],
#     'solver': ['adam', 'sgd'],
#     'alpha': uniform(0.0001, 0.01),
#     'learning_rate': ['constant', 'adaptive']
# }
# # 
# # Perform Randomized Search on Random Forest
# rf_clf = RandomForestClassifier(random_state=42)
# rf_random = RandomizedSearchCV(estimator=rf_clf, param_distributions=rf_param_grid,
#                                n_iter=10, cv=3, random_state=42, n_jobs=-1)
# rf_random.fit(X_train_resampled, y_train_resampled)
# y_pred_rf = rf_random.predict(X_test)
# rf_report = classification_report(y_test, y_pred_rf, target_names=label_encoder.classes_)

# # Perform Randomized Search on XGBoost
# xgb_clf = XGBClassifier(random_state=42)
# xgb_random = RandomizedSearchCV(estimator=xgb_clf, param_distributions=xgb_param_grid,
#                                 n_iter=10, cv=3, random_state=42, n_jobs=-1)
# xgb_random.fit(X_train_resampled, y_train_resampled)
# y_pred_xgb = xgb_random.predict(X_test)
# xgb_report = classification_report(y_test, y_pred_xgb, target_names=label_encoder.classes_)

# # Perform Randomized Search on ANN (MLP)
# ann_clf = MLPClassifier(random_state=42, max_iter=500)
# ann_random = RandomizedSearchCV(estimator=ann_clf, param_distributions=ann_param_grid,
#                                 n_iter=10, cv=3, random_state=42, n_jobs=-1)
# ann_random.fit(X_train_resampled, y_train_resampled)
# y_pred_ann = ann_random.predict(X_test)
# ann_report = classification_report(y_test, y_pred_ann, target_names=label_encoder.classes_)

# # Display the classification reports for all models
# print("Random Forest Classification Report:")
# print(rf_report)

# print("XGBoost Classification Report:")
# print(xgb_report)

# print("ANN Classification Report:")
# print(ann_report)

# # Best parameters for each model
# print("Best Random Forest Parameters:", rf_random.best_params_)
# print("Best XGBoost Parameters:", xgb_random.best_params_)
# print("Best ANN Parameters:", ann_random.best_params_)
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/zhangtianjie/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 21 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/zhangtianjie/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, StackingClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Load the dataset
df = pd.read_csv(r'full_results_with_predictions.csv')

# Select features (including 'Prediction Correct') and the target ('Chloride Ion Penetrability')
X = df[['AGE', 'PC1', 'PC2', 'PC1_TYPE', 'FA', 'SS', 'SF', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 
        'VOID', 'w/b', 'b/a', 'SCM%', 'APPLICATION_ID']].values
y = df['Chloride Ion Penetrability']


# Convert target labels (Permeability Level) to numerical labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Base models
rf_clf = RandomForestClassifier(n_estimators=200, random_state=42)  # Random Forest
xgb_clf = XGBClassifier(random_state=42)  # XGBoost
ann_clf = MLPClassifier(hidden_layer_sizes=(100,), max_iter=300, random_state=42)  # Neural Network
gb_clf = GradientBoostingClassifier(random_state=42)  # Gradient Boosting
svm_clf = SVC(probability=True, random_state=42)  # Support Vector Classifier (with probabilities)

# Meta-model: XGBoost (this will combine the predictions of the base models)
meta_clf = XGBClassifier(random_state=42)

# Stacking Classifier with more base models and XGBoost as the final model
stacking_clf = StackingClassifier(
    estimators=[('rf', rf_clf), ('xgb', xgb_clf), ('ann', ann_clf), ('gb', gb_clf), ('svm', svm_clf)],
    final_estimator=meta_clf,
    passthrough=True  # Pass original features along with base model predictions to the meta-model
)

# Train the StackingClassifier
stacking_clf.fit(X_train, y_train)

# Predict using the stacked model
y_pred_stacked = stacking_clf.predict(X_test)

# Classification report for the stacked model
stacked_report = classification_report(y_test, y_pred_stacked, target_names=label_encoder.classes_)

# Display the results
print("Stacking Classifier Report:")
print(stacked_report)
# Out:
# Stacking Classifier Report:
#               precision    recall  f1-score   support
#
#         High       0.50      0.09      0.15        11
#          Low       0.57      0.64      0.60        58
#     Moderate       0.27      0.38      0.32        16
#     Very Low       0.86      0.83      0.85       121
#
#     accuracy                           0.70       206
#    macro avg       0.55      0.48      0.48       206
# weighted avg       0.72      0.70      0.70       206

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Load the dataset
df = pd.read_csv(r'final_dataset.csv')

# Select features (including 'Prediction Correct') and the target ('Chloride Ion Penetrability')
X = df[['AGE', 'PC1', 'PC2', 'PC1_TYPE', 'FA', 'SS', 'SF', 'CAGG', 'WATER', 'AEA', 'WR_HR', 'WR', 'ACC', 
        'VOID', 'w/b', 'b/a', 'SCM%', 'APPLICATION_ID']].values
y = df['Chloride Ion Penetrability']

# Convert target labels (Permeability Level) to numerical labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets (20% test data)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Bagging - Resample 80% of the training data
X_train, _, y_train, _ = train_test_split(X_train_full, y_train_full, train_size=0.8, random_state=42)

# Base models (Random Forest, XGBoost, CatBoost, LightGBMXT, ANN)
rf_clf = RandomForestClassifier(n_estimators=200, random_state=42)
xgb_clf = XGBClassifier(random_state=42)
catboost_clf = CatBoostClassifier(silent=True, random_state=42)
lgbmxt_clf = LGBMClassifier(boosting_type='goss', random_state=42)
ann_clf_base = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)

# Perform Cross-validation with bagging for each base model
rf_pred = cross_val_predict(rf_clf, X_train, y_train, cv=5)
xgb_pred = cross_val_predict(xgb_clf, X_train, y_train, cv=5)
catboost_pred = cross_val_predict(catboost_clf, X_train, y_train, cv=5)
lgbmxt_pred = cross_val_predict(lgbmxt_clf, X_train, y_train, cv=5)
ann_pred = cross_val_predict(ann_clf_base, X_train, y_train, cv=5)

# Combine predictions as new features for the meta-model
stacked_features = pd.DataFrame({
    'rf_pred': rf_pred.ravel(),  # Ensuring 1-dimensional
    'xgb_pred': xgb_pred.ravel(),
    'catboost_pred': catboost_pred.ravel(),
    'lgbmxt_pred': lgbmxt_pred.ravel(),
    'ann_pred': ann_pred.ravel()
})

# Meta-model: ANN
meta_clf = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)
meta_clf.fit(stacked_features, y_train)

# Predict on the test set using the stacked model
rf_test_pred = rf_clf.fit(X_train, y_train).predict(X_test)
xgb_test_pred = xgb_clf.fit(X_train, y_train).predict(X_test)
catboost_test_pred = catboost_clf.fit(X_train, y_train).predict(X_test)
lgbmxt_test_pred = lgbmxt_clf.fit(X_train, y_train).predict(X_test)
ann_test_pred = ann_clf_base.fit(X_train, y_train).predict(X_test)

# Combine test set predictions for final evaluation
stacked_test_features = pd.DataFrame({
    'rf_pred': rf_test_pred.ravel(),
    'xgb_pred': xgb_test_pred.ravel(),
    'catboost_pred': catboost_test_pred.ravel(),
    'lgbmxt_pred': lgbmxt_test_pred.ravel(),
    'ann_pred': ann_test_pred.ravel()
})

# Final meta-model prediction on the test set
y_pred_stacked = meta_clf.predict(stacked_test_features)

# Classification report for the stacked model
stacked_report = classification_report(y_test, y_pred_stacked, target_names=label_encoder.classes_)

# Display the results
print("Stacking Classifier with Bagging, Cross-Validation, and Meta ANN Report:")
print(stacked_report)
# Out:
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000176 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 779
# [LightGBM] [Info] Number of data points in the train set: 527, number of used features: 17
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] Start training from score -3.048325
# [LightGBM] [Info] Start training from score -1.325558
# [LightGBM] [Info] Start training from score -2.335375
# [LightGBM] [Info] Start training from score -0.527408
# ...
